# %% [markdown]
# <a href="https://colab.research.google.com/github/allanhue/Data-Science/blob/main/Bank%20statements%20dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Sample data for the bank statement
data = {
    "Date": [
        "2025-11-01",
        "2025-11-02",
        "2025-11-03",
        "2025-11-05",
        "2025-11-07",
        "2025-11-10",
        "2025-11-13"
    ],
    "Description": [
        "Opening Balance",
        "Payment to Supplier",
        "Customer Deposit",
        "Utility Bill",
        "Cash Deposit",
        "Salary Payment",
        "Received from Client"
    ],
    "Withdrawal": [
        "",           # Opening balance, no withdrawal
        "2000.00",
        "",           # Customer deposit, no withdrawal
        "500.00",
        "",           # Cash Deposit, no withdrawal
        "3500.00",
        ""            # Received from client, no withdrawal
    ],
    "Deposit": [
        "",           # Opening balance, no deposit
        "",           # Payment to supplier, no deposit
        "5000.00",
        "",           # Utility bill, no deposit
        "1500.00",
        "",           # Salary payment, no deposit
        "2000.00"
    ],
    "Balance": [
        "10000.00",
        "8000.00",
        "13000.00",
        "12500.00",
        "14000.00",
        "10500.00",
        "12500.00"
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Save as Excel (XLSX)
df.to_excel("sample_bank_statement.xlsx", index=False)

# Save as CSV
df.to_csv("sample_bank_statement.csv", index=False)
files.download

# %%
from google.colab import files

files.download('sample_bank_statement.xlsx')
